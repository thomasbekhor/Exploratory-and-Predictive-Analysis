# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("DATA1_housing.csv")

data2=pd.read_csv("DATA2_passengers.csv")
from sklearn.model_selection import train_test_split
data2_train,data2_test = train_test_split(data2, train_size=0.6, test_size=0.4, shuffle=True)

X_train=data2_train["PassengerId"]
Y_train=data2_train["Transported"]
X_test=data2_test["PassengerId"]
Y_test=data2_test["Transported"]

# %%
data2.head(20)
# Out:
#    PassengerId HomePlanet CryoSleep  Cabin    Destination   Age    VIP  \
# 0      0001_01     Europa     False  B/0/P    TRAPPIST-1e  39.0  False
# 1      0002_01      Earth     False  F/0/S    TRAPPIST-1e  24.0  False
# 2      0003_01     Europa     False  A/0/S    TRAPPIST-1e  58.0   True
# 3      0003_02     Europa     False  A/0/S    TRAPPIST-1e  33.0  False
# 4      0004_01      Earth     False  F/1/S    TRAPPIST-1e  16.0  False
# 5      0005_01      Earth     False  F/0/P  PSO J318.5-22  44.0  False
# 6      0006_01      Earth     False  F/2/S    TRAPPIST-1e  26.0  False
# 7      0006_02      Earth      True  G/0/S    TRAPPIST-1e  28.0  False
# 8      0007_01      Earth     False  F/3/S    TRAPPIST-1e  35.0  False
# 9      0008_01     Europa      True  B/1/P    55 Cancri e  14.0  False
# 10     0008_02     Europa      True  B/1/P    TRAPPIST-1e  34.0  False
# 11     0008_03     Europa     False  B/1/P    55 Cancri e  45.0  False
# ...

# %% [markdown]
# # Scikit-Learn
#
# A principal biblioteca para Machine Learning em Python chama-se Scikit-Learn, ou de modo abreviado `sklearn`. Com esta biblioteca podemos construir modelos de aprendizado de máquina bem sofisticados, exceto para *deep learning*, onde outras bibliotecas são usadas (e.g. Keras, Theano, TensorFlow).

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
# Cria modelo.
model = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("classifier", MultinomialNB())
])

# Treina modelo.
model.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('classifier', MultinomialNB())])

# %%
# Testa modelo.
y_pred = model.predict(X_test)

# Calcula acurácia.
acc = accuracy_score(Y_test, y_pred)

print("Acurácia: {}".format(acc))
# Out:
# Acurácia: 0.503737780333525

# %%
### Função utilitária para fazer a regressão com constante adicionada
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
#dataframe só com os tansportes == a true
filtro=data2_train["Transported"]==True
dadosTran=data2_train.loc[filtro,:]
dadosTran.head()
#dataframe só com os transportes igual a falso
filtro=data2_train["Transported"]==False
dadosN=data2_train.loc[filtro,:]

# %%
#pegando value counts de cada variavel
print("value counts do dados Tran==True")
dicio_homeplanet_Tran=dadosTran["HomePlanet"].value_counts()
print(dicio_homeplanet_Tran)
dicio_CryoSleep_Tran=dadosTran["CryoSleep"].value_counts()
print(dicio_CryoSleep_Tran)
#dicio_Cabin_Tran=dadosTran["Cabin"].value_counts()
#print(dicio_Cabin_Tran)
dicio_Destination_Tran=dadosTran["Destination"].value_counts()
print(dicio_Destination_Tran)
dicio_Age_Tran=dadosTran["Age"].value_counts()
print(dicio_Age_Tran)
dicio_VIP_Tran=dadosTran["VIP"].value_counts()
print(dicio_VIP_Tran)
#dicio_RoomService_Tran=dadosTran["RoomService"].value_counts()
#print(dicio_RoomService_Tran)
#dicio_FoodCourt_Tran=dadosTran["FoodCourt"].value_counts()
#print(dicio_FoodCourt_Tran)
#dicio_ShoppingMall_Tran=dadosTran["ShoppingMall"].value_counts()
#print(dicio_ShoppingMall_Tran)
#dicio_Spa_Tran=dadosTran["Spa"].value_counts()
#print(dicio_Spa_Tran)
#dicio_VRDeck_Tran=dadosTran["VRDeck"].value_counts()
#print(dicio_VRDeck_Tran)
#dicio_Name_Tran=dadosTran["Name"].value_counts()
#print(dicio_Name_Tran)
# Out:
# value counts do dados Tran==True
# Earth     1166
# Europa     852
# Mars       535
# Name: HomePlanet, dtype: int64
# True     1510
# False    1054
# Name: CryoSleep, dtype: int64
# TRAPPIST-1e      1640
# 55 Cancri e       684
# PSO J318.5-22     243
# Name: Destination, dtype: int64
# 18.0    112
# 24.0     91
# 28.0     90
# 0.0      85
# 23.0     84
#        ...
# 66.0      2
# 69.0      1
# 78.0      1
# 77.0      1
# 76.0      1
# Name: Age, Length: 76, dtype: int64
# False    2523
# True       46
# Name: VIP, dtype: int64

# %%
#pegando value counts de cada variavel
print("value counts do dados Tran==True")
dicio_homeplanet_N=dadosN["HomePlanet"].value_counts()
print(dicio_homeplanet_N)
dicio_CryoSleep_N=dadosN["CryoSleep"].value_counts()
print(dicio_CryoSleep_N)
#dicio_Cabin_N=dadosN["Cabin"].value_counts()
#print(dicio_Cabin_N)
dicio_Destination_N=dadosN["Destination"].value_counts()
print(dicio_Destination_N)
dicio_Age_N=dadosN["Age"].value_counts()
print(dicio_Age_N)
dicio_VIP_N=dadosN["VIP"].value_counts()
print(dicio_VIP_N)
#dicio_RoomService_N=dadosN["RoomService"].value_counts()
#print(dicio_RoomService_N)
#dicio_FoodCourt_N=dadosN["FoodCourt"].value_counts()
#print(dicio_FoodCourt_N)
#dicio_ShoppingMall_N=dadosN["ShoppingMall"].value_counts()
#print(dicio_ShoppingMall_N)
#dicio_Spa_N=dadosN["Spa"].value_counts()
#print(dicio_Spa_N)
#dicio_VRDeck_N=dadosN["VRDeck"].value_counts()
#print(dicio_VRDeck_N)
#dicio_Name_N=dadosN["Name"].value_counts()
#print(dicio_Name_N)
# Out:
# value counts do dados Tran==True
# Earth     1587
# Mars       491
# Europa     452
# Name: HomePlanet, dtype: int64
# False    2190
# True      337
# Name: CryoSleep, dtype: int64
# TRAPPIST-1e      1870
# 55 Cancri e       424
# PSO J318.5-22     244
# Name: Destination, dtype: int64
# 21.0    118
# 24.0    100
# 19.0     98
# 22.0     97
# 18.0     96
#        ...
# 75.0      2
# 66.0      1
# 78.0      1
# 68.0      1
# 79.0      1
# Name: Age, Length: 75, dtype: int64
# False    2448
# True       76
# Name: VIP, dtype: int64

# %%
chaves=["PassengerId","HomePlanet","CryoSleep","Cabin","Destination","Age","VIP","RoomService","FoodCourt","ShoppingMall","Spa","VRDeck","Name"]
print(data2_train.groupby(by="Transported").HomePlanet.value_counts())
dicio=data2_train.groupby(by="Transported").HomePlanet.value_counts()
print("embaixo como navega")
print(dicio[0][0])

print(data2_train.groupby(by="Transported").Destination.value_counts())
# Out:
# Transported  HomePlanet
# False        Earth         1587
#              Mars           491
#              Europa         452
# True         Earth         1166
#              Europa         852
#              Mars           535
# Name: HomePlanet, dtype: int64
# embaixo como navega
# 1587
# Transported  Destination
# False        TRAPPIST-1e      1870
#              55 Cancri e       424
#              PSO J318.5-22     244
# True         TRAPPIST-1e      1640
#              55 Cancri e       684
#              PSO J318.5-22     243
# Name: Destination, dtype: int64
